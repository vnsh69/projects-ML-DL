# %% [markdown]
# <a href="https://colab.research.google.com/github/vnsh69/projects-ML-DL/blob/main/weather_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###https://drive.google.com/file/d/1igKqRbENjlP3RA-lA7f1_pMfP_8Q2XKQ/view?usp=sharing

# %%
import gdown

file_id = "1igKqRbENjlP3RA-lA7f1_pMfP_8Q2XKQ"
url = f"https://drive.google.com/uc?id={file_id}"
output = "data.csv"  # Change filename if needed

gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1igKqRbENjlP3RA-lA7f1_pMfP_8Q2XKQ
# From (redirected): https://drive.google.com/uc?id=1igKqRbENjlP3RA-lA7f1_pMfP_8Q2XKQ&confirm=t&uuid=06c331c1-5156-43fe-a15c-6c59befc0785
# To: /content/data.csv
# 100%|██████████| 4.33G/4.33G [00:50<00:00, 86.1MB/s]
# 'data.csv'

# %%
df = pd.read_csv('data.csv')
print(df.head())
# Out:
#                             time     frequency  sweep   range  volume_number  \
# 0  2024-09-25 08:00:11.000000000  9.425000e+09      0   31.25              1
# 1  2024-09-25 08:00:11.000000000  9.425000e+09      0   93.75              1
# 2  2024-09-25 08:00:11.000000000  9.425000e+09      0  156.25              1
# 3  2024-09-25 08:00:11.000000000  9.425000e+09      0  218.75              1
# 4  2024-09-25 08:00:11.000000000  9.425000e+09      0  281.25              1
#
#     latitude  longitude  altitude      time_coverage_start  \
# 0  19.107285  72.837303      37.0  b'2024-09-25T08:00:11Z'
# 1  19.107285  72.837303      37.0  b'2024-09-25T08:00:11Z'
# 2  19.107285  72.837303      37.0  b'2024-09-25T08:00:11Z'
# 3  19.107285  72.837303      37.0  b'2024-09-25T08:00:11Z'
# 4  19.107285  72.837303      37.0  b'2024-09-25T08:00:11Z'
#
#          time_coverage_end  ...  URHOHV     UPHIDP   UNCPH   UNCPV  FSNRHC  \
# 0  b'2024-09-25T08:06:38Z'  ...  0.8301  185.64000  0.5372  0.7882    7.33
# 1  b'2024-09-25T08:06:38Z'  ...  0.9999  284.46000  1.0000  1.0000   12.94
# 2  b'2024-09-25T08:06:38Z'  ...  0.9998  307.03998  1.0000  1.0000   28.90
# 3  b'2024-09-25T08:06:38Z'  ...  0.9993  328.22000  1.0000  1.0000   39.68
# 4  b'2024-09-25T08:06:38Z'  ...  0.9962    7.76000  1.0000  1.0000   44.43
#
#       FSNRVC  UVELH  UVELV  UWIDTHH UWIDTHV
# 0   9.490000    1.2    0.6     1.94    0.89
# 1  18.109999    0.0    0.0     0.07    0.07
# 2  29.330000    0.0    0.0     0.07    0.07
# 3  37.520000    0.0    0.0     0.07    0.07
# 4  41.840000    0.0    0.0     0.07    0.07
#
# [5 rows x 59 columns]

# %%
df.isnull().sum()
# Out:
# time                               0
# frequency                          0
# sweep                              0
# range                              0
# volume_number                      0
# latitude                           0
# longitude                          0
# altitude                           0
# time_coverage_start                0
# time_coverage_end                  0
# azimuth                            0
# elevation                          0
# radar_antenna_gain_h               0
# radar_antenna_gain_v               0
# radar_beam_width_h                 0
# radar_beam_width_v                 0
# radar_receiver_bandwidth           0
# radar_measured_transmit_power_h    0
# radar_measured_transmit_power_v    0
# pulse_width                        0
# prt                                0
# prt_ratio                          0
# nyquist_velocity                   0
# n_samples                          0
# prt_mode                           0
# polarization_mode                  0
# sweep_number                       0
# sweep_mode                         0
# fixed_angle                        0
# sweep_start_ray_index              0
# sweep_end_ray_index                0
# UH                                 0
# UV                                 0
# DBZH                               0
# DBZV                               0
# ZDR                                0
# RHOHV                              0
# PHIDP                              0
# NCPH                               0
# NCPV                               0
# SNRHC                              0
# SNRVC                              0
# VELH                               0
# VELV                               0
# WIDTHH                             0
# WIDTHV                             0
# CCORH                              0
# CCORV                              0
# UZDR                               0
# URHOHV                             0
# UPHIDP                             0
# UNCPH                              0
# UNCPV                              0
# FSNRHC                             0
# FSNRVC                             0
# UVELH                              0
# UVELV                              0
# UWIDTHH                            0
# UWIDTHV                            0
# dtype: int64

# %%
df = df.ffill()
